# %% [markdown]
# # Understanding How to Apply Linear Regression

# %% [markdown]
# ## Understanding Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Size_sqft  Bedrooms  Age_years  Distance_city_km  House_Price
# 0        850         2         20              12.0       145000
# 1        900         2         18              10.0       155000
# 2        950         3         15               8.0       175000
# 3       1000         3         12               7.0       190000
# 4       1100         3         10               6.0       210000

# %%
df.describe()
# Out:
#          Size_sqft    Bedrooms   Age_years  Distance_city_km    House_Price
# count   100.000000  100.000000  100.000000        100.000000     100.000000
# mean   1685.000000    4.350000    6.450000          3.729000  362920.000000
# std     557.524289    1.320965    6.526365          3.891905  157693.839673
# min     850.000000    2.000000    1.000000          0.300000  135000.000000
# 25%    1185.000000    3.000000    1.000000          0.750000  217500.000000
# 50%    1670.000000    4.500000    4.000000          2.000000  350000.000000
# 75%    2155.000000    5.250000   10.000000          6.000000  495000.000000
# max    2640.000000    6.000000   24.000000         15.000000  640000.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Size_sqft         100 non-null    int64
#  1   Bedrooms          100 non-null    int64
#  2   Age_years         100 non-null    int64
#  3   Distance_city_km  100 non-null    float64
#  4   House_Price       100 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 4.0 KB

# %%
plt.hist(df["House_Price"])
# Out:
# (array([18., 12.,  8., 10.,  7., 10.,  9.,  6., 10., 10.]),
#  array([135000., 185500., 236000., 286500., 337000., 387500., 438000.,
#         488500., 539000., 589500., 640000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["Size_sqft"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11cfda660>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11cfda900>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11cfda510>],
#  'medians': [<matplotlib.lines.Line2D at 0x11cfdaba0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11cfdacf0>],
#  'means': []}

# %%
plt.scatter(df["Size_sqft"], df["House_Price"])

# %% [markdown]
# #### Linear Regression Must be Applied as correlation between data is Linear
